# %%
import os
import re
from datetime import datetime,timedelta
import pandas as pd

# %%
path = "Measurements"
dir_list = os.listdir(path)
print(dir_list)
# Out:
# ['measure_122-9-27-9-47-25-769_Samples600_History60.csv', 'measure_122-9-27-9-48-25-954_Samples600_History60.csv', 'measure_122-9-27-9-49-26-188_Samples600_History60.csv', 'measure_122-9-27-9-50-26-323_Samples600_History60.csv', 'measure_122-9-27-9-51-26-518_Samples600_History60.csv', 'measure_122-9-27-9-52-26-711_Samples600_History60.csv', 'measure_122-9-27-9-53-1-785_Samples600_History60.csv']

# %%
def GetParameter(fileName, key):
    x = re.search(key+"\d+", fileName)
    y = re.search("\d+", x[0])
    return int(y.group())
def GetFinalTimeStamp(file):
    x = re.search("(\d*-\d*){6}", file)
    dateStr = x[0][1:]
    date = datetime.strptime(dateStr, "%y-%m-%d-%H-%M-%S-%f")
    #print(date2.strftime("%y-%m-%d-%H-%M-%S-%f"))
    return date
def GetTimeStampIncrement(date, increment):
    return date + timedelta(milliseconds=increment)

def AddTimeStamps(df,date,frequency):
    dates = [date]
    for i in range(1,len(df)):
        dates.append(GetTimeStampIncrement(dates[-1],-frequency*1000))
    strDates = [x.strftime("%y-%m-%d-%H-%M-%S-%f") for x in dates]
    df['TimeStamp'] = strDates

def AddPowers(df,key, frequency):
    lst = df[key]
    watt = [key]
    for i in range(0,len(lst)-1):
        watt.append(lst[i]*10*230*frequency)
    df[key+"Power(joule)"] = watt

# %%
for file in dir_list:
    Samples = GetParameter(file, "Samples")
    History = GetParameter(file, "History")
    Date = GetFinalTimeStamp(file)
    frequency = History/Samples
    df = pd.read_csv(path+"\\"+file)
    AddTimeStamps(df, Date, frequency)
    AddPowers(df,'C1TrueRMS ', frequency)
    AddPowers(df, 'C1ACRMS', frequency)
    print(df)
# Out:
#      C1TrueRMS    C1ACRMS                 TimeStamp C1TrueRMS Power(joule)  \
# 0      0.004835  0.001677  22-09-27-09-47-25-769000             C1TrueRMS
# 1      0.004785  0.001661  22-09-27-09-47-25-669000               1.112046
# 2      0.004434  0.001499  22-09-27-09-47-25-569000               1.100453
# 3      0.004888  0.001706  22-09-27-09-47-25-469000                1.01984
# 4      0.004475  0.001507  22-09-27-09-47-25-369000               1.124202
# ..          ...       ...                       ...                    ...
# 595    0.463580  0.101602  22-09-27-09-46-26-269000              42.816894
# 596    0.956070  0.231682  22-09-27-09-46-26-169000             106.623401
# 597    2.648323  0.686388  22-09-27-09-46-26-069000             219.896013
# 598    6.494549  1.719373  22-09-27-09-46-25-969000             609.114289
# 599   15.464697  3.853310  22-09-27-09-46-25-869000            1493.746292
#
#     C1ACRMSPower(joule)
# 0               C1ACRMS
# 1              0.385743
# 2              0.382091
# 3              0.344747
# 4              0.392414
# ..                  ...
# 595              7.2967
# 596            23.36849
# 597           53.286914
# 598          157.869195
# 599          395.455869
#
# [600 rows x 5 columns]
#      C1TrueRMS    C1ACRMS                 TimeStamp C1TrueRMS Power(joule)  \
# 0      0.005750  0.001868  22-09-27-09-48-25-954000             C1TrueRMS
# 1      0.005549  0.001866  22-09-27-09-48-25-854000               1.322397
# 0      0.005789  0.001878  22-09-27-09-51-26-518000             C1TrueRMS
# 1      0.005383  0.001839  22-09-27-09-51-26-418000                1.33148
# 2      0.005326  0.001829  22-09-27-09-51-26-318000               1.237987
# 3      0.005574  0.001865  22-09-27-09-51-26-218000               1.225004
# 4      0.005593  0.001868  22-09-27-09-51-26-118000                1.28205
# ..          ...       ...                       ...                    ...
# 595    0.004613  0.001578  22-09-27-09-50-27-018000               1.056515
# 596    0.004529  0.001556  22-09-27-09-50-26-918000               1.060904
# 597    0.004589  0.001589  22-09-27-09-50-26-818000               1.041619
# 598    0.005012  0.001753  22-09-27-09-50-26-718000               1.055466
# 599    0.004949  0.001730  22-09-27-09-50-26-618000                1.15278
#
#     C1ACRMSPower(joule)
# 0               C1ACRMS
# 1              0.431992
# 2               0.42299
# 3              0.420697
# 4                 0.429
# ..                  ...
# 595            0.368873
# 596            0.362961
# 597            0.357937
# 598            0.365576
# 599             0.40318
#
# [600 rows x 5 columns]
#      C1TrueRMS    C1ACRMS                 TimeStamp C1TrueRMS Power(joule)  \
# 0      0.004806  0.001671  22-09-27-09-52-26-711000             C1TrueRMS
# 1      0.004796  0.001665  22-09-27-09-52-26-611000               1.105415
# 2      0.004863  0.001696  22-09-27-09-52-26-511000               1.103147
# 3      0.004495  0.001544  22-09-27-09-52-26-411000               1.118399
# 4      0.004689  0.001622  22-09-27-09-52-26-311000               1.033833
# ..          ...       ...                       ...                    ...
# 595    0.005603  0.001874  22-09-27-09-51-27-211000               1.367617
# 596    0.006103  0.001848  22-09-27-09-51-27-111000               1.288669
# 597    0.006169  0.001837  22-09-27-09-51-27-011000               1.403594
# 598    0.006236  0.001813  22-09-27-09-51-26-911000               1.418878
# 599    0.006216  0.001813  22-09-27-09-51-26-811000               1.434284
#
#     C1ACRMSPower(joule)
# 0               C1ACRMS
# 1              0.384318
# 2              0.382836
# 3              0.390009
# 4              0.355146
# ..                  ...
# 595            0.430193
# 596            0.430937
# 597            0.425127
# 598            0.422578
# 599            0.416912
#
# [600 rows x 5 columns]
#      C1TrueRMS    C1ACRMS                 TimeStamp C1TrueRMS Power(joule)  \
# 0      0.005306  0.001823  22-09-27-09-53-01-785000             C1TrueRMS
# 1      0.006118  0.001844  22-09-27-09-53-01-685000               1.220311
# 2      0.006297  0.001793  22-09-27-09-53-01-585000                1.40712
# 3      0.005838  0.001872  22-09-27-09-53-01-485000               1.448197
# 4      0.006102  0.001845  22-09-27-09-53-01-385000               1.342822
# ..          ...       ...                       ...                    ...
# 595    0.005293  0.001813  22-09-27-09-52-02-285000               1.123644
# 596    0.005919  0.001877  22-09-27-09-52-02-185000               1.217397
# 597    0.005536  0.001867  22-09-27-09-52-02-085000               1.361271
# 598    0.005582  0.001863  22-09-27-09-52-01-985000               1.273356
# 599    0.005953  0.001879  22-09-27-09-52-01-885000                1.28386
#
#     C1ACRMSPower(joule)
# 0               C1ACRMS
# 1              0.419246
# 2              0.424016
# 3               0.41237
# 4              0.430578
# ..                  ...
# 595            0.393879
# 596            0.417007
# 597            0.431631
# 598            0.429329
# 599            0.428556
#
# [600 rows x 5 columns]
